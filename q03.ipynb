# %%
from google.colab import drive
#monta o drive do google drive
drive.mount("/content/drive") 

import os
#muda o diretório do google drive para o indicado abaixo
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from moduloq03 import *

while (1):
  print("====================================")
  print("1-inserir continente")
  print("2-inserir pais")
  print("3-populacao total")
  print("4-dimensao total")
  print("5-menor populacao")
  print("6-maior populacao")
  print("7-menor territorio")
  print("8-maior territorio")
  print("9-razao menor e maior territorio")
  print("10-sair")
  print("====================================")
  controle = int(input())
  
  if controle == 1:
    nome = input("Digite o nome do continente: ")
    a = continente(nome)
  if controle == 2:
    nome_pais = input('Digite o nome do pais')
    populacao_pais = int(input('Digite a populacao do pais'))
    territorio_pais = float(input('Digite o territorio do pais'))

    a.add_pais(nome_pais, populacao_pais, territorio_pais)
  
  if controle == 3:
    print(a.populacao_total())

  if controle == 4:
    print(a.dimensao_continente())

  if controle == 5:
    print(a.menor_populacao())

  if controle == 6:
    print(a.maior_populacao())

  if controle == 7:
    print(a.menor_territorio())

  if controle == 8:
    print(a.maior_territorio())
  
  if controle == 9:
    print(a.razao_menor_maior())
    
  if controle == 10:
    break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-a0633dce09f0> in <module>()
# ----> 1 from moduloq03 import *
#       2
#       3 while (1):
#       4   print("====================================")
#       5   print("1-inserir continente")
#
# ModuleNotFoundError: No module named 'moduloq03'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
