# %%
from google.colab import drive
#monta o drive do google drive
drive.mount("/content/drive") 

import os
#muda o diretório do google drive para o indicado abaixo
os.chdir("/content/drive/My Drive/Colab Notebooks")

# %%
from Np2moduloq01 import *
while(1):
    
    print("==============================")
    print("1-Incluir novo produto")
    print("2-Listar todos produtos")
    print("3-Adicionar ao estoque")
    print("4-Retirar do estoque")
    print("5-Excluir produto")
    print("6-sair")
    print("==============================")

    controle = int(input())

    if controle == 1:
        #USUÁRIO INFORMA OS DADOS.
        nome = input("Digite o nome do produto a inserir: ")
        qtd = int(input("Digite a quantidade de {}: ".format(nome)))
        inserir(nome, qtd)
        conn.commit()
    
    if controle == 2:
        leitura()
        conn.commit()
    
    if controle == 3:
        #USUÁRIO INFORMA OS DADOS.
        nome = input("Digite o nome do produto a adicionar a quantidade: ")
        qtd = int(input("Digite a quantidade de {}: ".format(nome)))
        adicionar(nome, qtd)
        conn.commit()

    if controle == 4:
        nome = input("Digite o nome do produto a retirar do estoque: ")
        qtd = input("Digite a quantidade de {} a retirar do estoque: ".format(nome))
        retirar(nome, qtd)
        conn.commit()

    if controle == 5:
        nome = str(input("Digite o nome do produto a excluir: "))
        excluir(nome)
        conn.commit()

    if controle == 6:
        break

cursor.close()
conn.close()
