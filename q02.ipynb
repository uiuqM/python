# %%
from google.colab import drive
#monta o drive do google drive
drive.mount("/content/drive") 

import os
#muda o diretório do google drive para o indicado abaixo
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from moduloq02 import *

while (1):
  print("==============================")
  print("1-inserir dados")
  print("2-calcular idade")
  print("3-calcular frequancia maxima")
  print("4-calcular frequencia ideal")
  print("5-sair")
  print("==============================")
  controle = int(input())
  
  if controle == 1:
    a = BatimentosCardiacos()
    nome = input("Digite o nome: ")
    sobrenome = input("Digite o sobrenome: ")
    data_nasc = input("Digite a data de nascimento: ")
    a.setnome(nome)
    a.setsobrenome(sobrenome)
    a.setdata_nascimento(data_nasc)

  if controle == 2:
    print(a.calculaIdade())
  
  if controle == 3:
    print(a.calculaFrequenciaMax())

  if controle == 4:
    a.calculaBatimentoIdeal()

  if controle == 5:
    break
# Out:
# ...
# 1-inserir dados
# 2-calcular idade
# 3-calcular frequancia maxima
# 4-calcular frequencia ideal
# 5-sair
# ...
# 5
