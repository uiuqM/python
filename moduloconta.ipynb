# %%
class conta:
    numconta=0
    nome=""
    saldo=0.0
    chequeEspecial = bool
    limiteCE = 0.0
    
    def __init__(self,numconta,nome,saldo=None, chequeEspecial, limiteCE):
        if saldo is None:
            self.saldo=0
        else:
            self.saldo=saldo
            
        self.numconta=numconta
        self.nome=nome
        self.chequeEspecial = True
        self.limiteCE = 0.0
        
    def alteranome(self,n):
        self.nome=n
        
    def deposito(self,v):
        self.saldo=self.saldo+v
    
    def saque(self,v):
      if(self.saldo-v<=0):
        chequeEspecial == False
        print('Impossivel sacar valor!!!')
      if(chequeEspecial == True):
        self.saldo=self.saldo-v
      
        
    def mostradados(self):
        print("No. da conta=",self.numconta," Nome=",self.nome," Saldo=",self.saldo)
