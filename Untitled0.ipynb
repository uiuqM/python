# %%
class Aluno:
  nome = str
  idade = int
  numperiodos = int
  mediaporperiodo = []

  def __init__(self, nome=None, idade=None, numperiodos=None):
    if nome is None:
      self.nome = ''
    else:
      self.nome = nome
    if self.idade is None:
      self.idade = 0
    else:
      self.idade = idade
    if self.numperiodos is None:
      self.numperiodos = 0
    else:
      self.numperiodos = numperiodos
  
  def ledadosAluno(self):
    self.nome = str(input('Digite o nome do aluno:'))
    self.idade = int(input('Digite a idade:'))
    self.numperiodos = int(input('Digite quantos periodos: '))
    for i in range(self.numperiodos):
      media = float(input("Digite a media do periodo {}".format(i)))
      self.mediaporperiodo.append(media)
  def mostraDadosAluno(self):
    print('{} {} {}'.format(self.nome, self.idade, self.anoingresso))
  #def calculaMediaGeral(self):
