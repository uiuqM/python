# %%
from google.colab import drive
#monta o drive do google drive
drive.mount("/content/drive") 

import os
#muda o diretório do google drive para o indicado abaixo
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Mounted at /content/drive

# %%
from moduloq01 import *
while 1:
  print("======================================")
  print("1-adicionar Pais")
  print("2-verificar país")
  print("3-verificar fronteira")
  print("4-densidade populacional")
  print("5-verificar paises fronteiras")
  print("6-sair")
  print("======================================")
  controle = int(input())
  qtd = 0

  if controle == 1:
    a = []
    aux = 0
    a.append(pais())
    codigo = input("Digite o codigo do pais: ")
    nome = input("Digite o nome do pais: ")
    populacao = int(input("Insira a populacao: "))
    dimensao = float(input("Digite a area do pais em km2: "))
    fronteira = input("Digite os paises com o qual faz fronteira: ")
    fronteira = fronteira.split()

    a[aux].setcodigo(codigo)
    a[aux].setnome(nome)
    a[aux].setpopulacao(populacao)
    a[aux].setdimensao(dimensao)
    a[aux].setfronteira(fronteira)

    aux+=1
    qtd +=1
  if controle == 2:
    if len(a)>1:
      aux = a[0]
      for i in range(1, len(a)-1):
        aux.verifica_pais(a[i])

  if controle == 3:
    for i in range(1, len(a)-1):
      a[0].verifica_fronteira(a[i])
  
  if controle == 4:
    print(a[qtd].densidade())
  
  if controle == 5:
    if len(a)>1:
      aux = a[0]
      for i in range(1, len(a)-1):
        aux.verifica_vizinho(a[i])
  if controle == 6:
    break
# Out:
# ...
# 1-adicionar Pais
# 2-verificar país
# 3-verificar fronteira
# 4-densidade populacional
# 5-verificar paises fronteiras
# 6-sair
# ...
# 1
# Digite o codigo do pais: bra
# Digite o nome do pais: brasil
# Insira a populacao: 80
# Digite a area do pais em km2: 4
# Digite os paises com o qual faz fronteira: argentina uruguai
# ...
# 1-adicionar Pais
# 2-verificar país
# 3-verificar fronteira
# 4-densidade populacional
# 5-verificar paises fronteiras
# 6-sair
# ...
# 1
# Digite o codigo do pais: arg
# Digite o nome do pais: argentina
# Insira a populacao: 60
# Digite a area do pais em km2: 3
# Digite os paises com o qual faz fronteira: brasil portugal
# ...
# 1-adicionar Pais
# 2-verificar país
# 3-verificar fronteira
# 4-densidade populacional
# 5-verificar paises fronteiras
# 6-sair
# ...
# 3
# ...
# 1-adicionar Pais
# 2-verificar país
# 3-verificar fronteira
# 4-densidade populacional
# 5-verificar paises fronteiras
# 6-sair
# ...
# 6
