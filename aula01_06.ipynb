# %%
from google.colab import drive
#monta o drive do google drive
drive.mount("/content/drive") 

import os
#muda o diretório do google drive para o indicado abaixo
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from moduloquadrado import *

q0 = quadrado(4)
q1 = quadrado()
q0.retVal()
q1.retVal()
q1.mudarVal()
q1.retVal()
q0.calcArea()
# Out:
# Lado do quadrado: 4
# Lado do quadrado: 0
# Digite o tamanho para o lado: 2
# Lado do quadrado: 2.0
# 16

# %% [markdown]
# Faça um programa que crie a classe Conta Corrente: Crie uma classe para implementar uma conta
# corrente. A classe deve possuir os seguintes atributos: número da conta, nome do correntista e
# saldo. Os métodos são os seguintes: alterarNome, depósito e saque; No construtor, saldo é
# opcional, com valor default zero e os demais atributos são obrigatórios.

# %%
class contacorrente:
  numConta = int()
  nomeCorrentista = str()
  saldo = 0
  def __init__(self, numConta, nomeCorrentista, saldo = None):
    if self.saldo is None:
      self.saldo = 0
    else:
      self.saldo = saldo
    self.numConta = numConta
    self.nomeCorrentista = nomeCorrentista

  def alteraNome(self):
    self.nomeCorrentista = str(input('Digite o nome do correntista:'))
  def deposito(self):
    self.saldo =
